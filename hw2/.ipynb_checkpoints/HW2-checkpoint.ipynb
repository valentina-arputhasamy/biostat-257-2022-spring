# %% [markdown]
# ## Biostat 257 Homework 2

# %%
versioninfo()
# Out:
# Julia Version 1.7.2
# Commit bf53498635 (2022-02-06 15:21 UTC)
# Platform Info:
#   OS: macOS (x86_64-apple-darwin19.5.0)
#   CPU: Intel(R) Core(TM) i5-8210Y CPU @ 1.60GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-12.0.1 (ORCJIT, skylake)

# %%
#load libraries
using BenchmarkTools, DelimitedFiles, Images, LinearAlgebra, Random

# %% [markdown]
# ## Q1: Non-Negative Matrix Factorization

# %% [markdown]
# Nonnegative matrix factorization (NNMF) was introduced by Lee and Seung (1999) as an analog of principal components and vector quantization with applications in data compression and clustering. In this homework we consider algorithms for fitting NNMF and (optionally) high performance computing using graphical processing units (GPUs).
#
# In mathematical terms, one approximates a data matrix $\mathbf{X} \in \mathbb{R}^{m \times n}$ with nonnegative entries $x_{ij}$ by a product of two low-rank matrices $\mathbf{V} \in \mathbb{R}^{m \times r}$ and $\mathbf{W} \in \mathbb{R}^{r \times n}$ with nonnegative entries $v_{ik}$ and $w_{kj}$. Consider minimization of the squared Frobenius norm:
#
# $$ L(\mathbf{V}, \mathbf{W}) = \|\mathbf{X} - \mathbf{V} \mathbf{W}\|_{\text{F}}^2 = \sum_i \sum_j \left(x_{ij} - \sum_k v_{ik} w_{kj} \right)^2, \quad v_{ik} \ge 0, w_{kj} \ge 0,$$
#
# which should lead to a good factorization. Lee and Seung suggest an iterative algorithm with multiplicative updates:
#
# $$ v_{ik}^{(t+1)} = v_{ik}^{(t)} \frac{\sum_j x_{ij} w_{kj}^{(t)}}{\sum_j b_{ij}^{(t)} w_{kj}^{(t)}}, \quad \text{where } b_{ij}^{(t)} = \sum_k v_{ik}^{(t)} w_{kj}^{(t)}, $$
#
# $$ w_{kj}^{(t+1)} = w_{kj}^{(t)} \frac{\sum_i x_{ij} v_{ik}^{(t+1)}}{\sum_i b_{ij}^{(t+1/2)} v_{ik}^{(t+1)}}, \quad \text{where } b_{ij}^{(t+1/2)} = \sum_k v_{ik}^{(t+1)} w_{kj}^{(t)} $$
#
# that will drive the objective $L^{(t)} = L(\mathbf{V}^{(t)}, \mathbf{W}^{(t)})$ downhill. Superscript $t$ indicates iteration number. In following questions, efficiency (both speed and memory) will be the most important criterion when grading this problem.

# %% [markdown]
# ### Q1.1 Develop Code

# %% [markdown]
# Implement the algorithm with arguments: $\mathbf{X}$ (data, each row is a vectorized image), rank $r$, convergence tolerance, and optional starting point.

# %% [markdown]
# ### Solution:

# %% [markdown]
# #### Step 1: Develop Prototype of Function

# %%
function nnmf_prototype(
    X       :: Matrix{T}, 
    r       :: Integer;
    maxiter :: Integer = 1000, 
    tolfun  :: Number = 1e-4,
    V       :: Matrix{T} = rand(T, size(X, 1), r),
    W       :: Matrix{T} = rand(T, r, size(X, 2))
    ) where T <: AbstractFloat
    obj = norm(X - V * W)^2 # recording initial point of objective value
    # implementation
    niter = maxiter 
    # need to initialize or won't be able to find this var
    # set equal to maxiter because if convergence is never satisfied
    ## niter reported should be maxiter
    for iter in 1:maxiter
        # update V
        V .= V .* (X * W') ./ (V * W * W')
        # update W
        W .= W .* (V' * X) ./ (V' * V * W)
        # check convergence
        objold = obj # storing previous value of obj fcn
        obj = norm(X - V * W)^2 # refresh value of obj fcn with new V and W
        if abs(obj - objold) <= tolfun * (abs(objold) + 1) 
            # if this is satisfied we want to break out of the loop
            niter = iter # reporting iteration number
            break
        end
    end
    if niter == maxiter 
        @warn "maxiter reached without convergence"
    end
    # Output
    V, W, obj, niter
    
end
# Out:
# nnmf_prototype (generic function with 1 method)

# %% [markdown]
# #### Step 2: Optimize Code

# %%
function nnmf(
    X       :: Matrix{T}, 
    r       :: Integer;
    maxiter :: Integer = 1000, 
    tolfun  :: Number = 1e-4,
    V       :: Matrix{T} = rand(T, size(X, 1), r),
    W       :: Matrix{T} = rand(T, r, size(X, 2))
    ) where T <: AbstractFloat
    
    n,m = size(X)
    
    # implementation
    
    niter = maxiter 
    
    # need to initialize or won't be able to find this var
    # set equal to maxiter because if convergence is never satisfied
    ## niter reported should be maxiter  
    
    # setting up intermediate storage of components of obj fcn
    
    storageR = Matrix{T}(undef, r, r)
    storageV1 = similar(V) 
    storageV2 = similar(V)
    storageW1 = similar(W)
    storageW2 = similar(W)
    storageX = similar(X)
    x2norm = norm(X)^2
    
    # initial objective
    
    obj = x2norm # recording initial point of obj value
    mul!(storageR, transpose(V), V)
    mul!(storageW2, storageR, W)
    mul!(storageW1, transpose(V), X)
    
    @inbounds for idx in eachindex(W)                           
            obj = obj + storageW2[idx] - 2storageW1[idx] * W[idx]   
    end
    
    for iter in 1:maxiter
        # update V = V .* (X * W') ./ (V * W * W')
        mul!(storageR, W, transpose(W)) # multiply W and W' and store result in storageR # O(nr^2)
        mul!(storageV2, V, storageR) 
        mul!(storageV1, X, transpose(W))
        V .= V .* storageV1 ./ storageV2
        # update W = W .* (V' * X) ./ (V' * V * W)
        mul!(storageR, transpose(V), V)
        mul!(storageW2, storageR, W)
        mul!(storageW1, transpose(V), X)
        objold = obj
        obj = x2norm
        @inbounds for idx in eachindex(W)                           # little confused about this part
            obj = obj + storageW2[idx] - 2storageW1[idx] * W[idx]   # trying to make computation of obj fcn more efficient
            W[idx] = W[idx] * storageW1[idx] / storageW2[idx]         # but how?
        end
        W .= W .* storageW1 ./ storageW2
        
        # check convergence
     
        if abs(obj - objold) <= tolfun * (abs(objold) + 1) 
            # if this is satisfied we want to break out of the loop
            niter = iter # reporting iteration number
            break
        end
    end
    if niter == maxiter 
        @warn "maxiter reached without convergence"
    end
    # Output
    V, W, obj, niter
    
end
# Out:
# nnmf (generic function with 1 method)

# %% [markdown]
# ### Q1.2 Data

# %% [markdown]
# Database 1 from the [MIT Center for Biological and Computational Learning (CBCL)](http://cbcl.mit.edu) reduces to a matrix $\mathbf{X}$ containing $m = 2,429$ gray-scale face images with $n = 19 \times 19 = 361$ pixels per face. Each image (row) is scaled to have mean and standard deviation 0.25.
#
# Read in the [`nnmf-2429-by-361-face.txt`](https://raw.githubusercontent.com/ucla-biostat-257/2022spring/master/hw/hw2/nnmf-2429-by-361-face.txt) file, e.g., using [`readdlm`](https://docs.julialang.org/en/v1/stdlib/DelimitedFiles/#Delimited-Files) function, and display a couple sample images, e.g., using the [Images.jl](https://juliaimages.org/stable/) package.

# %% [markdown]
# ### Solution:

# %%
X = readdlm("nnmf-2429-by-361-face.txt") # each row is a face, goal: low rank approx of a face
colorview(Gray, reshape(X[1, :], 19, 19))
# Out:
# 19×19 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(0.14815)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.018294)     Gray{Float64}(0.027569)
#  Gray{Float64}(0.027569)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)          Gray{Float64}(0.0090181)
#  Gray{Float64}(0.083222)     Gray{Float64}(0.036844)
#  Gray{Float64}(0.10177)   …  Gray{Float64}(0.064671)
#  Gray{Float64}(0.38004)      Gray{Float64}(0.13887)
#  Gray{Float64}(0.51917)      Gray{Float64}(0.30583)
#  Gray{Float64}(0.43569)      Gray{Float64}(0.37076)
#  Gray{Float64}(0.38004)      Gray{Float64}(0.37076)
#  Gray{Float64}(0.29656)   …  Gray{Float64}(0.26873)
#  Gray{Float64}(0.25946)      Gray{Float64}(0.28728)
#  Gray{Float64}(0.31511)      Gray{Float64}(0.28728)
#  Gray{Float64}(0.2038)       Gray{Float64}(0.19453)
#  Gray{Float64}(0.083222)     Gray{Float64}(0.073946)
#  Gray{Float64}(0.018294)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.064671)     Gray{Float64}(0.0)
# ...

# %%
colorview(Gray, reshape(X[5, :], 19, 19))
# Out:
# 19×19 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(0.0082034)  …  Gray{Float64}(0.18099)
#  Gray{Float64}(0.0)           Gray{Float64}(0.018367)
#  Gray{Float64}(0.16066)       Gray{Float64}(0.0)
#  Gray{Float64}(0.0)           Gray{Float64}(0.0)
#  Gray{Float64}(0.059024)      Gray{Float64}(0.0)
#  Gray{Float64}(0.069188)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.2928)        Gray{Float64}(0.0082034)
#  Gray{Float64}(0.47575)       Gray{Float64}(0.12001)
#  Gray{Float64}(0.36394)       Gray{Float64}(0.17083)
#  Gray{Float64}(0.35378)       Gray{Float64}(0.27247)
#  Gray{Float64}(0.39444)    …  Gray{Float64}(0.31312)
#  Gray{Float64}(0.2928)        Gray{Float64}(0.32329)
#  Gray{Float64}(0.22165)       Gray{Float64}(0.27247)
#  Gray{Float64}(0.21148)       Gray{Float64}(0.22165)
#  Gray{Float64}(0.25214)       Gray{Float64}(0.22165)
#  Gray{Float64}(0.23181)    …  Gray{Float64}(0.17083)
# ...

# %%
colorview(Gray, reshape(X[14, :], 19, 19))
# Out:
# 19×19 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(0.1449)    …  Gray{Float64}(0.63537)
#  Gray{Float64}(0.078396)     Gray{Float64}(0.41923)
#  Gray{Float64}(0.0)          Gray{Float64}(0.011891)
#  Gray{Float64}(0.053457)     Gray{Float64}(0.11996)
#  Gray{Float64}(0.011891)     Gray{Float64}(0.16153)
#  Gray{Float64}(0.086709)  …  Gray{Float64}(0.31948)
#  Gray{Float64}(0.21972)      Gray{Float64}(0.53562)
#  Gray{Float64}(0.25297)      Gray{Float64}(0.61875)
#  Gray{Float64}(0.22803)      Gray{Float64}(0.64369)
#  Gray{Float64}(0.21141)      Gray{Float64}(0.62706)
#  Gray{Float64}(0.23634)   …  Gray{Float64}(0.60212)
#  Gray{Float64}(0.35273)      Gray{Float64}(0.51899)
#  Gray{Float64}(0.51068)      Gray{Float64}(0.44417)
#  Gray{Float64}(0.69356)      Gray{Float64}(0.39429)
#  Gray{Float64}(0.91802)      Gray{Float64}(0.35273)
#  Gray{Float64}(1.0)       …  Gray{Float64}(0.35273)
# ...

# %%
colorview(Gray, reshape(X[25, :], 19, 19))
# Out:
# 19×19 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(0.075269)  Gray{Float64}(0.28137)   …  Gray{Float64}(0.0)
#  Gray{Float64}(0.075269)  Gray{Float64}(0.10618)      Gray{Float64}(0.0)
#  Gray{Float64}(0.013439)  Gray{Float64}(0.013439)     Gray{Float64}(0.0)
#  Gray{Float64}(0.013439)  Gray{Float64}(0.034049)     Gray{Float64}(0.0)
#  Gray{Float64}(0.10618)   Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.24015)   Gray{Float64}(0.023744)  …  Gray{Float64}(0.17832)
#  Gray{Float64}(0.43595)   Gray{Float64}(0.24015)      Gray{Float64}(0.3329)
#  Gray{Float64}(0.5287)    Gray{Float64}(0.47717)      Gray{Float64}(0.45656)
#  Gray{Float64}(0.539)     Gray{Float64}(0.7348)       Gray{Float64}(0.39473)
#  Gray{Float64}(0.44625)   Gray{Float64}(0.65236)      Gray{Float64}(0.26076)
#  Gray{Float64}(0.37412)   Gray{Float64}(0.54931)   …  Gray{Float64}(0.20924)
# ...

# %%
colorview(Gray, reshape(X[22, :], 19, 19))
# Out:
# 19×19 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(0.17133)   Gray{Float64}(0.28853)   …  Gray{Float64}(0.23726)
#  Gray{Float64}(0.090757)  Gray{Float64}(0.13471)      Gray{Float64}(0.12006)
#  Gray{Float64}(0.090757)  Gray{Float64}(0.23726)      Gray{Float64}(0.10541)
#  Gray{Float64}(0.17866)   Gray{Float64}(0.20063)      Gray{Float64}(0.23726)
#  Gray{Float64}(0.0)       Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)       Gray{Float64}(0.032157)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.22261)   Gray{Float64}(0.33248)      Gray{Float64}(0.17866)
#  Gray{Float64}(0.36911)   Gray{Float64}(0.39108)      Gray{Float64}(0.33981)
#  Gray{Float64}(0.43503)   Gray{Float64}(0.42771)      Gray{Float64}(0.36178)
#  Gray{Float64}(0.44968)   Gray{Float64}(0.46433)      Gray{Float64}(0.42771)
#  Gray{Float64}(0.48631)   Gray{Float64}(0.53758)   …  Gray{Float64}(0.49363)
# ...

# %% [markdown]
# ### Q1.3 Correctness and Efficiency

# %% [markdown]
# Report the run times, using `@time`, of your function for fitting NNMF on the MIT CBCL face data set at ranks $r=10, 20, 30, 40, 50$. For ease of comparison (and grading), please start your algorithm with the provided $\mathbf{V}^{(0)}$ (first $r$ columns of [`V0.txt`](https://raw.githubusercontent.com/ucla-biostat-257/2022spring/master/hw/hw2/V0.txt)) and $\mathbf{W}^{(0)}$ (first $r$ rows of [`W0.txt`](https://raw.githubusercontent.com/ucla-biostat-257/2022spring/master/hw/hw2/W0.txt)) and stopping criterion:
#
# $$\frac{|L^{(t+1)} - L^{(t)}|}{|L^{(t)}| + 1} \le 10^{-4}.$$

# %% [markdown]
# ### Solution:

# %%
V0full = readdlm("V0.txt")
W0full = readdlm("W0.txt")
# Out:
# 50×361 Matrix{Float64}:
#  0.5634    0.32048   0.067202   0.25107   …  0.4476     0.12656   0.13688
#  0.71473   0.25423   0.084735   0.84327      0.20947    0.32729   0.43787
#  0.046351  0.041688  0.79152    0.8962       0.6786     0.17112   0.83691
#  0.76991   0.13366   0.0061026  0.70588      0.4457     0.012722  0.64244
#  0.56335   0.35408   0.62697    0.94923      0.073816   0.62934   0.58596
#  0.13659   0.82449   0.17183    0.051802  …  0.87725    0.86247   0.45418
#  0.2326    0.92296   0.73855    0.35246      0.015108   0.68424   0.15457
#  0.95628   0.97221   0.94922    0.59106      0.49038    0.52232   0.4399
#  0.82876   0.33257   0.95808    0.11028      0.66812    0.69979   0.57679
#  0.33585   0.59454   0.75948    0.26544      0.34689    0.071471  0.020196
#  0.87571   0.83349   0.83207    0.57283   …  0.34609    0.22545   0.2295
#  0.27631   0.10171   0.4809     0.10614      0.0039955  0.92647   0.27393
# ...

# %%
for r in [10, 20, 30, 40, 50]
    println("r=$r")
    V0 = V0full[:, 1:r]
    W0 = W0full[1:r, :]
    @time V, W, obj, niter = nnmf(X, r; V = V0, W = W0)
    println("obj=$obj, niter=$niter")
end
# Out:
# r=10
#   0.803041 seconds (719.19 k allocations: 43.551 MiB, 69.69% compilation time)
# obj=-73013.63901894419, niter=81
# r=20
#   0.461392 seconds (24 allocations: 7.545 MiB)
# obj=-84053.74316517542, niter=133
# r=30
#   0.438661 seconds (24 allocations: 7.975 MiB)
# obj=-87823.92420246308, niter=111
# r=40
#   0.309230 seconds (24 allocations: 8.406 MiB)
# obj=-89040.93324370055, niter=71
# r=50
#   0.491906 seconds (25 allocations: 8.839 MiB)
# obj=-92051.40303868835, niter=91

# %% [markdown]
# ### Q1.4 Non-uniqueness

# %% [markdown]
# Choose an $r \in \{10, 20, 30, 40, 50\}$ and start your algorithm from a different $\mathbf{V}^{(0)}$ and $\mathbf{W}^{(0)}$. Do you obtain the same objective value and $(\mathbf{V}, \mathbf{W})$? Explain what you find.

# %% [markdown]
# ### Solution:
#
# As can be seen below, the objective funtions for $r \in \{10, 20, 30, 40, 50\}$ using the default values of $\mathbf{V}^{(0)}$ and $\mathbf{W}^{(0)}$ set in the function `nnmf` are similar, but not exactly the same as the the objective values obtained using the values of $\mathbf{V}^{(0)}$ and $\mathbf{W}^{(0)}$ in part 3.

# %%
for r in [10, 20, 30, 40, 50]
    println("r=$r")
    @time V, W, obj, niter = nnmf(X, r)
    println("obj=$obj, niter=$niter")
end
# Out:
# r=10
#   2.798836 seconds (58 allocations: 7.332 MiB)
# obj=-76769.36801253566, niter=1000
# r=20
#   0.453437 seconds (26 allocations: 7.971 MiB)
# obj=-84229.74731590574, niter=145
# r=30
#   1.343833 seconds (26 allocations: 8.614 MiB)
# obj=-89785.5052838132, niter=327
# r=40
#   0.270696 seconds (26 allocations: 9.257 MiB)
# obj=-88141.78805914469, niter=60
# r=50
#   0.299844 seconds (27 allocations: 9.903 MiB)
# obj=-88658.54794835144, niter=53
# ┌ Warning: maxiter reached without convergence
# └ @ Main In[159]:68

# %% [markdown]
# ### Q1.4 Non-uniqueness

# %% [markdown]
# For the same $r$, start your algorithm from $v_{ik}^{(0)} = w_{kj}^{(0)} = 1$ for all $i,j,k$. Do you obtain the same objective value and $(\mathbf{V}, \mathbf{W})$? Explain what you find.

# %% [markdown]
# ### Solution:

# %% [markdown]
# As we can see in the output below, we can see that the objective values for all values of $r \in \{10, 20, 30, 40, 50\}$ are different yet again when we change $\mathbf{V}^{(0)}$ and $\mathbf{W}^{(0)}$. ### CHECK WITH SOMEONE

# %%
for r in [10, 20, 30, 40, 50]
    println("r=$r")
    V0 = ones(2429, r)
    W0 = ones(r, 361)
    @time V, W, obj, niter = nnmf(X, r; V = V0, W = W0)
    println("obj=$obj, niter=$niter")
end
# Out:
# r=10
#   2.017506 seconds (26 allocations: 7.117 MiB)
# obj=-74788.42824099344, niter=743
# r=20
#   2.582147 seconds (26 allocations: 7.545 MiB)
# obj=-72124.69508069784, niter=717
# r=30
#   3.391527 seconds (26 allocations: 7.975 MiB)
# obj=-69537.55329039088, niter=729
# r=40
#   5.063090 seconds (56 allocations: 8.407 MiB)
# obj=-54078.7440176686, niter=1000
# r=50
#   4.406238 seconds (27 allocations: 8.839 MiB)
# obj=-69544.44189024014, niter=745
# ┌ Warning: maxiter reached without convergence
# └ @ Main In[159]:68

# %% [markdown]
# ### Q1.6 Interpret NNMF result

# %% [markdown]
# Plot the basis images (rows of $\mathbf{W}$) at rank $r=50$. What do you find?

# %%
for image = 1:50
print("image=$image")
display(colorview(Gray, reshape(W[image, :], 19, 19)))
end
# Out:
# image=1
# 19×19 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(2.00947e-15)  …  Gray{Float64}(2.78986e-8)
#  Gray{Float64}(6.67719e-15)     Gray{Float64}(0.000189284)
#  Gray{Float64}(7.88024e-13)     Gray{Float64}(0.00503243)
#  Gray{Float64}(1.43784e-13)     Gray{Float64}(9.84016e-6)
#  Gray{Float64}(1.24839e-13)     Gray{Float64}(4.52539e-5)
#  Gray{Float64}(4.83403e-9)   …  Gray{Float64}(0.144171)
#  Gray{Float64}(0.00105637)      Gray{Float64}(138.349)
#  Gray{Float64}(2.52538)         Gray{Float64}(1524.04)
#  Gray{Float64}(437.955)         Gray{Float64}(6053.58)
#  Gray{Float64}(2591.97)         Gray{Float64}(13975.3)
#  Gray{Float64}(3060.0)       …  Gray{Float64}(15975.3)
#  Gray{Float64}(2281.08)         Gray{Float64}(19900.9)
#  Gray{Float64}(1310.79)         Gray{Float64}(18594.5)
#  Gray{Float64}(953.225)         Gray{Float64}(10312.5)
#  Gray{Float64}(88.6531)         Gray{Float64}(2670.36)
# ...

# %% [markdown]
# ### Q2: Estimating Kinship Matrix

# %% [markdown]
# Consider the numerical task of estimating an  𝑛×𝑛  kinship matrix  Φ  from an  𝑛×𝑚  genotype matrix  𝐆 . Here  𝑛  is the number of individuals and  𝑚  is the number of genetic markers. Lange et al derived a method of moment estimator of form:
#
# $$ \widehat \Phi_{ij} = \frac{e_{ij} - \sum_{k=1}^m [p_k^2 + (1 - p_k)^2]}{m - \sum_{k=1}^m [p_k^2 + (1 - p_k)^2]}, \quad 1 \le i, j \le n, $$
#
# where
#
# \begin{align}
# e_{ij} &= \frac{1}{4} \sum_{k=1}^m [g_{ik} g_{jk} + (2 - g_{ik})(2 - g_{jk})] \\
# p_k &= \frac {1}{2n} \sum_{i=1}^n g_{ik}
# \end{align}

# %% [markdown]
# ### Q2.1 Develop code

# %% [markdown]
# Write a function that takes a matrix G as input and outputs the method of moment estimator. Make your function as efficient (both speed and memory) as possible.

# %% [markdown]
# ### Solution:

# %%
function kinship(G::Matrix{T}) where T <: AbstractFloat
    n, m = size(G)
    Φ = zeros(n, n)
    r = zeros(T,n) # double check this
    c = 0.0

    # implementation
    
    for j = 1:m
        pj = 0.0
        for i = 1:n
            r[i] += G[i,j] # collecting all row sums of G into an nx1 vector (need for calculation of e)
            pj += G[i,j] # calculating jth column sum and NOT storing it in a vector 
        end
        pj = pj/(2n) # pj is equal to pk in q. it is the sum of the elements in the kth column of G div by 2n
        c += 2*(pj^2 - pj) # evaluating summation of pk^2 + (1 - pk)^2 doing this loop to calculate the 
                               ## constant prevents us having to allocate a vector for p
    end
    
    Φ .= (.5 .* (mul!(Φ, G, G') .- r .- transpose(r)) .- c) ./ (-c)
    
    # output
    Φ
end
# Out:
# kinship (generic function with 1 method)

# %% [markdown]
# ### Q2.2 Correctness

# %% [markdown]
# First let's make sure our function yields correct answer. Run your function on a fake genotype matrix.

# %% [markdown]
# ### Solution:

# %%
# generate a fake genotype matrix with entries {0, 1, 2}
Random.seed!(257)
G = rand(0.0:2.0, 1000, 10000)
Φ = kinship(G)
# Out:
# 1000×1000 Matrix{Float64}:
#   0.673584     -0.000762864  -0.00266412   …   0.0108448    -0.00446532
#  -0.000762864   0.665178     -0.0101691        0.00994423   -0.00136326
#  -0.00266412   -0.0101691     0.665078        -0.0157728    -0.00356472
#   0.00343992   -0.0110697     0.0102444        0.0106447     0.00514105
#   0.00293959    0.00223912    0.00253932      -0.00506571    0.00163873
#  -0.00226386   -0.00626651   -0.00876817   …   0.00834317    0.00494091
#   0.00684217   -0.00516578    0.00384018      -0.00486558    0.00604164
#   0.00404032    0.00524111   -0.00816777      -0.00236392   -0.00696697
#   0.000237799   0.00233919    0.0129462       -0.0012632    -0.00296432
#   0.00564138   -0.00366479    0.0108448       -0.00736724    0.0154479
#   0.00574144   -0.00606638    0.00203899   …   0.00273946   -0.00736724
#  -0.00326452   -0.00856803   -0.000162467      0.00183886   -0.0089683
#   0.000638064   0.00293959   -0.00306439      -0.00496565   -0.00156339
# ...

# %% [markdown]
# Compare the upper left  5×5  block of the results of my implementation to the results from Dr. Zhou's implementation.

# %%
Φ[1:5, 1:5]
# Out:
# 5×5 Matrix{Float64}:
#   0.673584     -0.000762864  -0.00266412   0.00343992   0.00293959
#  -0.000762864   0.665178     -0.0101691   -0.0110697    0.00223912
#  -0.00266412   -0.0101691     0.665078     0.0102444    0.00253932
#   0.00343992   -0.0110697     0.0102444    0.66768     -0.0083679
#   0.00293959    0.00223912    0.00253932  -0.0083679    0.663777

# %% [markdown]
# ### Q2.3 Efficiency

# %% [markdown]
# In a typical genetic data set,  𝑛  is at order of  103∼106  and  𝑚  is at order of  106∼107 . Benchmark your function using the smaller data set  𝐺  generated in Q2.2. Efficiency (both speed and memory) will be the most important criterion when grading this question.

# %%
# benchmark
@btime kinship($G)
# Out:
#   169.599 ms (3 allocations: 7.64 MiB)
# 1000×1000 Matrix{Float64}:
#   0.673584     -0.000762864  -0.00266412   …   0.0108448    -0.00446532
#  -0.000762864   0.665178     -0.0101691        0.00994423   -0.00136326
#  -0.00266412   -0.0101691     0.665078        -0.0157728    -0.00356472
#   0.00343992   -0.0110697     0.0102444        0.0106447     0.00514105
#   0.00293959    0.00223912    0.00253932      -0.00506571    0.00163873
#  -0.00226386   -0.00626651   -0.00876817   …   0.00834317    0.00494091
#   0.00684217   -0.00516578    0.00384018      -0.00486558    0.00604164
#   0.00404032    0.00524111   -0.00816777      -0.00236392   -0.00696697
#   0.000237799   0.00233919    0.0129462       -0.0012632    -0.00296432
#   0.00564138   -0.00366479    0.0108448       -0.00736724    0.0154479
#   0.00574144   -0.00606638    0.00203899   …   0.00273946   -0.00736724
#  -0.00326452   -0.00856803   -0.000162467      0.00183886   -0.0089683
# ...

# %% [markdown]
# ### Solution:

# %% [markdown]
# My `@btime` output is 169.599ms with 3 allocations. I believe that I'm not able to bring down my runtime due to the age and model of my laptop.
